# %%
import requests
import json
import pandas as pd
import xml
import os
from dotenv import load_dotenv

# %%
# curl -XGET 'https://tradestie.com/api/v1/apps/reddit?date=2022-04-03'
url = 'https://tradestie.com/api/v1/apps/reddit'
params = {
    'date':'2022-04-20'
}
# response = requests.get('http://waterservices.usgs.gov/nwis/iv/?format=json&stateCd=va&parameterCd=00010,00060,00061,00065&siteType=ST&siteStatus=active',
# headers={'Accept-Encoding': 'gzip'})
response = requests.get(url=url, params=params)
parsed = response.json()

# %%
pd.DataFrame(parsed)
# Out:
#     no_of_comments sentiment  sentiment_score ticker
# 0              333   Bullish            0.257   TSLA
# 1              305   Bullish            0.984   NFLX
# 2               63   Bullish            0.130    GME
# 3               36   Bullish            0.196     TV
# 4               34   Bullish            0.420     FB
# 5               27   Bullish            0.159    AMC
# 6               22   Bullish            0.788   CVNA
# 7               21   Bearish            0.000    DIS
# 8               13   Bearish           -0.340   TWTR
# 9               13   Bullish            0.190    AMD
# 10              10   Bullish            0.151     TA
# 11               9   Bullish            0.218    QQQ
# 12               8   Bullish            0.026     UK
# 13               7   Bullish            0.220   PLTR
# 14               7   Bullish            0.710    EOD
# 15               7   Bullish            0.298     AI
# 16               7   Bullish            0.153   IBKR
# ...

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
load_dotenv()
params = {
    'function':'TIME_SERIES_INTRADAY',
    'symbol':'TSLA',
    'interval':'60min',
    'apikey':os.environ.get('alphavantage_api_key'),
    'outputsize':'full'
}

r = requests.get(url=url, params=params)
data = r.json()

data
# Out:
# {'Meta Data': {'1. Information': 'Intraday (60min) open, high, low, close prices and volume',
#   '2. Symbol': 'TSLA',
#   '3. Last Refreshed': '2022-11-18 20:00:00',
#   '4. Interval': '60min',
#   '5. Output Size': 'Full size',
#   '6. Time Zone': 'US/Eastern'},
#  'Time Series (60min)': {'2022-11-18 20:00:00': {'1. open': '179.3900',
#    '2. high': '179.4000',
#    '3. low': '179.0600',
#    '4. close': '179.3000',
#    '5. volume': '81755'},
#   '2022-11-18 19:00:00': {'1. open': '179.4500',
#    '2. high': '179.5200',
#    '3. low': '179.1500',
#    '4. close': '179.4000',
#    '5. volume': '74541'},
#   '2022-11-18 18:00:00': {'1. open': '179.9800',
#    '2. high': '180.1900',
#    '3. low': '179.2000',
#    '4. close': '179.4500',
#    '5. volume': '223067'},
#   '2022-11-18 17:00:00': {'1. open': '180.1900',
#    '2. high': '180.3500',
#    '3. low': '179.9500',
#    '4. close': '179.9800',
#    '5. volume': '1231913'},
#   '2022-11-18 16:00:00': {'1. open': '178.4950',
# ...

# %%
test = os.environ.get('alphavantage_api_key')
alphavantage_api_key
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10740\3561995053.py in <module>
#       1 test = os.environ.get('alphavantage_api_key')
# ----> 2 alphavantage_api_key
#
# NameError: name 'alphavantage_api_key' is not defined

# %%
p
# Out:
# dict_keys(['sourceInfo', 'variable', 'values', 'name'])

# %%
df = pd.DataFrame(parsed)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10740\3580725618.py in <module>
# ----> 1 df = pd.DataFrame(parsed)
#       2 df.head()
#
# c:\Users\jhcip\personal_data_projects\USGS_water_data_Go\.venv\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# c:\Users\jhcip\personal_data_projects\USGS_water_data_Go\.venv\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     463
# ...
